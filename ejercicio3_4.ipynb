# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Calcular tamaño total de los intervalos
N = 7500 + 8400 + 5700 + 3000
N
# Out:
# 24600

# %%
# Calcular proporcion
p = 375/7500
p
print(f"En cada estrato se esocge el {p*100}% de su tamaño")
# Out:
# En cada estrato se esocge el 5.0% de su tamaño

# %%
n1 = 375
n2 = p*8400
n3 = p*5700
n4 = p*3000

print(f"La compisición de la muestra 1: {n1}")
print(f"La compisición de la muestra 2: {n2}")
print(f"La compisición de la muestra 3: {n3}")
print(f"La compisición de la muestra 4: {n4}")
print(f"El tamaño total de la muestra es: {n1+n2+n3+n4}")
# Out:
# La compisición de la muestra 1: 375
# La compisición de la muestra 2: 420.0
# La compisición de la muestra 3: 285.0
# La compisición de la muestra 4: 150.0
# El tamaño total de la muestra es: 1230.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt
# Estandarizar el valor para calcular la probabilidad bajo una distribución normal estandar
u = 7.5 
o = 0.3
x = 7
n = 5
m = (x-u)/(o/sqrt(n))
m # seria el valor de z estandarizado
# Out:
# -3.7267799624996503

# %%
from scipy.stats import norm

u = 0
o = 1
P = norm.cdf(m)

print("La probabilidad de que el contenido en la muestra de medicamentos sea menor a 7 gramos es:", P)
# Out:
# La probabilidad de que el contenido en la muestra de medicamentos sea menor a 7 gramos es: 9.697081455185922e-05
