# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
import numpy as np

# %% [markdown]
# ## Diferentes plots
# * Diagramas de dispersión o puntos.
# * Diagramas de barras.
# * Histograma.
# * Diagramas de caja y bigotes.

# %% [markdown]
# #### Diagrama de Dispersión

# %%
# Generar datos aleatorios para x e y
x = np.random.randn(100)
y = np.random.randn(100)

# Crear un diagrama de dispersión
fig, ax = plt.subplots()
ax.scatter(x, y)

# Establecer las etiquetas de los ejes y el título
ax.set_xlabel('Variable X')
ax.set_ylabel('Variable Y')
ax.set_title('Diagrama de Dispersión')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Diagrama de Barras

# %%
# Generar datos aleatorios para el eje x e y
x = np.array(['A', 'B', 'C', 'D', 'E'])
y = np.random.rand(5)

# Crear un diagrama de barras
fig, ax = plt.subplots()
ax.bar(x, y)

# Establecer las etiquetas de los ejes y el título
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Diagrama de Barras')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Histograma

# %%
# Generar datos aleatorios para el eje x
x = np.random.randn(1000)

# Crear un histograma
fig, ax = plt.subplots()
ax.hist(x, bins=20)

# Establecer las etiquetas de los ejes y el título
ax.set_xlabel('X')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Diagrama de Caja

# %%
# Generar datos aleatorios para el eje x
x = np.random.randn(1000)

# Crear un diagrama de caja
fig, ax = plt.subplots()
ax.boxplot(x)

# Establecer las etiquetas de los ejes y el título
ax.set_xlabel('X')
ax.set_title('Diagrama de Caja y Bigotes')

# Mostrar el gráfico
plt.show()

# %%
fig.savefig('boxplot.png')

# %%
# Create the figure and axes objects
fig, ax = plt.subplots(figsize=(8,8))
# Set up the map projection
m = Basemap(llcrnrlon=-119, llcrnrlat=22, urcrnrlon=-64, urcrnrlat=49, projection='lcc', lat_1=33, lat_2=45, lon_0=-95, resolution='l', area_thresh=1000, ax=ax)

# Draw the coastlines and states
m.drawcoastlines(linewidth=0.5)
m.drawstates(linewidth=0.5)

# Fill in the land areas with green shading
m.etopo()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 fig, ax = plt.subplots(figsize=(8,8))
#       3 # Set up the map projection
# ----> 4 m = Basemap(llcrnrlon=-119, llcrnrlat=22, urcrnrlon=-64, urcrnrlat=49, projection='lcc', lat_1=33, lat_2=45, lon_0=-95, resolution='l', area_thresh=1000, ax=ax)
#       6 # Draw the coastlines and states
#       7 m.drawcoastlines(linewidth=0.5)
#
# NameError: name 'Basemap' is not defined

# %%
# Generar datos sintéticos
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Crear el objeto de figura y ejes
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar los datos con diferentes colores y marcadores
ax.plot(x, y1, color='red', marker='o', linestyle='-', label='Onda Seno')
ax.plot(x, y2, color='blue', marker='s', linestyle='--', label='Onda Coseno')

# Añadir etiquetas de los ejes y título
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_title('Ondas Seno y Coseno')

# Establecer límites en los ejes x e y
ax.set_xlim(0, 10)
ax.set_ylim(-1.2, 1.2)


# Personalizar los ticks de los ejes
ax.set_xticks(np.arange(0, 11, 2))
ax.set_yticks(np.arange(-1, 1.1, 0.5))

# Añadir una leyenda
ax.legend(loc='upper right')

# Añadir rejilla
ax.grid()

# Encontrar el máximo de la función seno
xmax = x[np.argmax(y)]
ymax = np.max(y)

# Añadir una anotación al máximo
ax.annotate(
    'Máximo',
    # xy=(xmax, ymax),
    xy=(2, 1),
    xytext=(3, 1),
    # textcoords='offset points',
    arrowprops=dict(
        facecolor='black',
        mutation_scale=200
    )
)

# Añadir etiquetas de los ejes y título

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {'metros': [1, 2, 3, 4, 5, 6, 7, 8],
     'ninos': [2, 6, 10, 5, 10, 3, 2, 2]}
)

weighted_median = np.average(df['metros'], weights=df['ninos'])
print(weighted_median)
# Out:
# 4.05

# %%
weighted_avg = (df['x'] * df['w']).sum() / df['w'].sum()

print(weighted_avg)
# Out:
# 4.05

# %%
std_w = np.sqrt(
    np.average(
        (df['metros'] - weighted_avg)**2,
        weights=df['ninos']
    )
)
print('Weighted Standard Deviation:', std_w)
# Out:
# Weighted Standard Deviation: 1.7599715906798041
