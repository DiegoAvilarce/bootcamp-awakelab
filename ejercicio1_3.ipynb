# %%
import pandas as pd
data = {'Metros': [1, 2, 3, 4, 5, 6, 7, 8],
        'Ninos': [2, 6, 10, 5, 10, 3, 2, 2]}

df = pd.DataFrame(data)
valores = []
for i in range(len(df.Metros)):
    for j in range(df.Ninos[i]):
        valores.append(df.Metros[i])
df_valores = pd.DataFrame(valores, columns=['Metros'])

df_valores
# Out:
#     Metros
# 0        1
# 1        1
# 2        2
# 3        2
# 4        2
# 5        2
# 6        2
# 7        2
# 8        3
# 9        3
# 10       3
# 11       3
# 12       3
# 13       3
# 14       3
# 15       3
# 16       3
# 17       3
# 18       4
# 19       4
# 20       4
# 21       4
# 22       4
# 23       5
# 24       5
# 25       5
# 26       5
# 27       5
# 28       5
# 29       5
# 30       5
# 31       5
# 32       5
# 33       6
# 34       6
# 35       6
# 36       7
# 37       7
# 38       8
# 39       8

# %% [markdown]
# # A)

# %%
# Tabla de frecuencias Ninos
frecuencia = df.Ninos.value_counts()
norm_frecuencia = df.Ninos.value_counts(normalize=True)

# calcular frecuencia acumulada
frecuencia_acumulada = frecuencia.cumsum()
norm_frecuencia_acumulada = norm_frecuencia.cumsum()

# %%
frecuencia.plot(kind='bar',title='Frecuencia Absoluta Ninos')
# Out:
# <Axes: title={'center': 'Frecuencia Absoluta Ninos'}, xlabel='Ninos'>

# %%
norm_frecuencia.plot(kind='bar',title='Frecuencia Relativa Ninos')
# Out:
# <Axes: title={'center': 'Frecuencia Relativa Ninos'}, xlabel='Ninos'>

# %%
frecuencia_acumulada.plot(kind='bar',title='Frecuencia Absoluta Acumulada Ninos')
# Out:
# <Axes: title={'center': 'Frecuencia Absoluta Acumulada Ninos'}, xlabel='Ninos'>

# %%
norm_frecuencia_acumulada.plot(kind='bar',title='Frecuencia Relativa Acumulada Ninos')
# Out:
# <Axes: title={'center': 'Frecuencia Relativa Acumulada Ninos'}, xlabel='Ninos'>

# %% [markdown]
# # B)

# %%
# calcular media, mediana y moda
media = df.Ninos.mean()
mediana = df.Ninos.median()
moda = df.Ninos.mode()
media,mediana,moda
# Out:
# (5.0,
#  4.0,
#  0    2
#  Name: Ninos, dtype: int64)

# %% [markdown]
# # C)

# %%
# calcular desviacion estandar y varianza
desvest = df.Ninos.std()
varianza = df.Ninos.var()

desvest, varianza
# Out:
# (3.4226138716316967, 11.714285714285714)

# %% [markdown]
# # D)

# %%
# establecer quantiles para el df
valores = df.Ninos.quantile([0.75,1])

print("Los valores que tenemos entre 75% y 100% de las observaciones son:")
for valor in valores:
    print(valor)
# Out:
# Los valores que tenemos entre 75% y 100% de las observaciones son:
# 7.0
# 10.0
